# %% [markdown]
# ### Lambda Function In python
#
# Lambda function are small anonymous functions (func without name) define using the lambda keyword. They can have any numberof arguments but only one expression, they are commonly used for short operations or as arguments to higher-order function.

# %%
# Syntax 

lambda arguments: expression

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition = lambda a,b: a+b
type(addition)
print(addition(2,3))
# Out:
# 5

# %%
def even(num):
    if num%2 ==0:
        return True
    
even(24)
# Out:
# True

# %%
even1 = lambda num: num%2 == 0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12, 13, 14)
# Out:
# 39

# %%
addition1  =  lambda x,y,z: x+y+z
addition1(12, 13, 14)
# Out:
# 39

# %%
## map() -  applies a functions to all items in a list 

numbers = [1,2,3,4,5]

def square(numbers):
    return numbers**2

square(2)
# Out:
# 4

# %%
list(map(lambda x: x**2, numbers))
# Out:
# [1, 4, 9, 16, 25]
