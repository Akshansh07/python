# %% [markdown]
# ### Introduction to Stramlit
#
# Streamlit is an open-source app framework for Machine lerning and data science projects. It allows you to create beautiful web applications for your machine learning and data sciemce projects with simple python script.
#
#
# streamlit run app.py = run the stream lit app
