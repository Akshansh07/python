# %%
## For loop 
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i  in range(10, 1, -2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
## Strings 

str = "Akshansh Dogra"

for i in str: 
    print(i)
# Out:
# A
# k
# s
# h
# a
# n
# s
# h
#
# D
# o
# g
# r
# a

# %%
## While loop 
## the while loop continues to execute as long as the condition is True.

count = 0

while count < 5:
    print(count)
    count = count + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count = 0

while count%2 == 0:
    print(count)
    count = count + 1
# Out:
# 0

# %%
## Loop control Statements 

## Break 
## Break statement exits the loop prematurely

for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## Continue
## Continue statement skips the current iteration and continues with the next.

for i in range(10):
    if i%2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
## Pass
## The pass statement is a null operation; it does nothing.
for i in range(5):
    if i == 3:
        print("This is a pass statement", i)
        pass
    print(i)
# Out:
# 0
# 1
# 2
# This is a pass statement 3
# 3
# 4

# %%
## Nesred lopps 
## a loop inside a loop

for i in range(3):
    for j in range(2):
        print(f"i: {i}, j: {j}")
# Out:
# i: 0, j: 0
# i: 0, j: 1
# i: 1, j: 0
# i: 1, j: 1
# i: 2, j: 0
# i: 2, j: 1

# %%
## Example 
# calculate the sum of first n natural number 

## While loop

n=10
sum=0
count=1 

while count <= n:
    sum = sum + count
    count = count + 1

print("sum of first 10 natural number is ", sum)
# Out:
# sum of first 10 natural number is  55

# %%
n = 10 
sum = 0
for i in range(11):
    sum = sum + i

print("sum of first 10 natural number is ", sum)
# Out:
# sum of first 10 natural number is  55

# %%
## disply prime number asbetween 1 to 100

for num in range(1, 101):
    if num>1:
        for i in range(2, num):
            if num%1 == 0:
                break
        else:
             print(num)
# Out:
# 2
