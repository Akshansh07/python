# %% [markdown]
# ### Polymorphism
#
# Polymorphism is core concept in Object-oriented propgrammong that allow objects of different classes to be trated as objects of a common supeclass it provides a way to perform a single actions in different forms. Polimorphism is typically achievd through method overriding and interfaces.

# %% [markdown]
# ### Method overriding
# Method overriding allow a child class to provide a specific implementation of a method that is already defined in its parent class.

# %%
## Base class

class Animal:
    def speak(self):
        return "sound of the animal"

## Derived class
class Dog(Animal):
    def speak(self):
        return "Woof!"

## Derived class
class Cat(Animal):
    def speak(self):
        return "Meow!"
    
## Function that demonstrates polymorphism

def animal_speak(animal):
    print(animal.speak())

dog = Dog()
cat = Cat()
print(dog.speak())  # Output: Woof!
print(cat.speak())  # Output: Meow!
animal_speak(dog)  # Output: Woof!
# Out:
# Woof!
# Meow!
# Woof!

# %%
### Polymorphism with function and methods 

## Base class
class Shape:
    def area(self):
        return "The area of figure"
    
## Derived class 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
## Derived class 2
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius
    
## Function that demonstrates polymorphism
def print_area(Shape):
    print(f"The area is {Shape.area()}")

rectangle = Rectangle(5, 3)
circle = Circle(4)
print_area(rectangle)  # Output: The area is 15
print_area(circle)     # Output: The area is 50.24
# Out:
# The area is 15
# The area is 50.24

# %% [markdown]
# ## Polymorphism with abstract base class
#
# Abstract base classes(ABCs) are used to define common methods for a group of related objects. They can enforce that derived classes implement particular methods, promoting consistence acress different implementations.

# %%
from abc import ABC, abstractmethod

## Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"

## Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"
    
## FUNCTION THAT DEMONSTRATES POLYMORPHISM
def start_vehicle(vehicle):
    print(vehicle.start_engine())
    
## Create object of Car and Motorcycle

car = Car()
motorcycle = Motorcycle()
start_vehicle(car)  # Output: Car engine started
# Out:
# Car engine started

# %% [markdown]
# ## Conclusion
#
# Polymorphism is a powerfull feature of OOP that allow for flexibility and integration in code design. In enable a single function to handle object of different classes, each with its own implementation of a method. By inderstanding and applying polymorphism, you can create more extensible and maintainable object-oriented program.
